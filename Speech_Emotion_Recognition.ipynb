# %% [markdown]
# <a href="https://colab.research.google.com/github/Kamal-Chandra/Speech--Emotion-Recognition/blob/main/Speech_Emotion_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Introduction**
#
# This project aims to build a machine learning model for **Speech Emotion Recognition (SER)**.
#
# **Speech Emotion Recognition** involves identifying human emotions and affective states from speech. This leverages the fact that tone and pitch in voice often convey underlying emotions. It's a phenomenon also observed in animals like dogs and horses, which use vocal cues to understand human emotions.
#
# **Dataset Used:**
#
# Ryerson Audio-Visual Database of Emotional Speech and Song (RAVDESS)

# %% [markdown]
# **Download RAVDESSS dataset and remove unnecessary files from it.**

# %%
import os
import shutil
import zipfile
import requests

url = "https://www.kaggle.com/api/v1/datasets/download/uwrfkaggler/ravdess-emotional-speech-audio?datasetVersionNumber=1"

response = requests.get(url)
zip_path = "/content/ravdess.zip"

# Write the content to a file
with open(zip_path, "wb") as file:
    file.write(response.content)

# Extract the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/ravdess")

# Path to the extracted dataset
RAVDESS = "/content/ravdess"

os.remove(zip_path)

path_to_delete = "/content/ravdess/audio_speech_actors_01-24"

if os.path.exists(path_to_delete):
    shutil.rmtree(path_to_delete)
else:
    print(f"Path does not exist: {path_to_delete}")

# %% [markdown]
# **Split the data into two parts:**
#
# **1. Training Set**
#
# **2. Test Set**

# %%
# Paths to the directories
train_set_path = os.path.join(RAVDESS, "Train Set")
test_set_path = os.path.join(RAVDESS, "Test Set")

# Create the subfolders if they don't exist
os.makedirs(train_set_path, exist_ok=True)
os.makedirs(test_set_path, exist_ok=True)

# List of actor folders in the RAVDESS directory
actor_folders = sorted([f for f in os.listdir(RAVDESS) if f.startswith("Actor_")])

for actor in actor_folders[0:20]:
    shutil.move(os.path.join(RAVDESS, actor), train_set_path)

for actor in actor_folders[20:24]:
    shutil.move(os.path.join(RAVDESS, actor), test_set_path)

# %% [markdown]
# ## **Filename identifiers as per the official RAVDESS website:**
#
# Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
#
# Vocal channel (01 = speech, 02 = song).
#
# Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 =
# fearful, 07 = disgust, 08 = surprised).
#
# Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.
#
# Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").
#
# Repetition (01 = 1st repetition, 02 = 2nd repetition).
# Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).
#
# ## Example:
#
# 02-01-06-01-02-01-12.mp4
#
# This means the meta data for the audio file is:
#
# Video-only (02)
#
# Speech (01)
#
# Fearful (06)
#
# Normal intensity (01)
#
# Statement "dogs" (02)
#
# 1st Repetition (01)
#
# 12th Actor (12) - Female (as the actor ID number is even)

# %%
# Define dictionary to map file name to emotions

emotions = {
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}

# Observing these emotions

observed_emotions = ['happy', 'sad', 'angry', 'fearful', 'neutral']

# %%
import numpy as np
import pandas as pd

import librosa
import librosa.display

# %%
# Training set data frame created from the given data

train_set_list = os.listdir(train_set_path)

data = []

for dir in train_set_list:
  actor = os.listdir(train_set_path+ '/'+ dir)
  for file in actor:
    part = file.split('.')[0]
    part = part.split('-')
    emotion = emotions.get(part[2], None)
    if emotion is not None and emotion in observed_emotions:
      file_path = os.path.join(train_set_path, dir, file)
      data.append({'Emotion': emotion, 'File_Path': file_path})

ravdess_df = pd.DataFrame(data)
print(ravdess_df)
# Out:
#      Emotion                                          File_Path
# 0        sad  /content/ravdess/Train Set/Actor_08/03-01-04-0...
# 1    fearful  /content/ravdess/Train Set/Actor_08/03-01-06-0...
# 2    fearful  /content/ravdess/Train Set/Actor_08/03-01-06-0...
# 3    neutral  /content/ravdess/Train Set/Actor_08/03-01-01-0...
# 4      angry  /content/ravdess/Train Set/Actor_08/03-01-05-0...
# ..       ...                                                ...
# 715    angry  /content/ravdess/Train Set/Actor_11/03-01-05-0...
# 716    happy  /content/ravdess/Train Set/Actor_11/03-01-03-0...
# 717  fearful  /content/ravdess/Train Set/Actor_11/03-01-06-0...
# 718  neutral  /content/ravdess/Train Set/Actor_11/03-01-01-0...
# 719    angry  /content/ravdess/Train Set/Actor_11/03-01-05-0...
#
# [720 rows x 2 columns]

# %% [markdown]
# ## **Data Augmentation**
#
# Data augmentation is a technique used to enhance the size and quality of the training dataset by applying various transformations to the existing data. This process helps in making the model more robust and better suited for real-world scenarios.
#
# ## **Benefits of Data Augmentation**
#
# Increases Training Set Size
#
# Enhances Model Robustness
#
# Improves Generalization

# %%
import soundfile as sf

# Constants
NOISE_FACTOR = 0.035
SHIFT_MAX = 0.5
PITCH_STEPS = 2
SPEED_FACTOR = 1.5

# Function to add noise to a signal
def add_noise(data, noise_factor=NOISE_FACTOR):
    noise = np.random.randn(len(data))
    augmented_data = data + noise_factor * noise
    return augmented_data

# Function to shift a signal in time
def shift_time(data, shift_max=SHIFT_MAX):
    shift = np.random.randint(int(len(data) * shift_max))
    augmented_data = np.roll(data, shift)
    return augmented_data

# Function to change the pitch of a signal
def change_pitch(data, sampling_rate, pitch_steps=PITCH_STEPS):
    return librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=pitch_steps)

# Function to change the speed of a signal
def change_speed(data, speed_factor=SPEED_FACTOR):
    return librosa.effects.time_stretch(data, rate=speed_factor)

# Apply data augmentation
augmented_data = []

for index, row in ravdess_df.iterrows():
    y, sr = librosa.load(row['File_Path'])

    # Apply noise injection
    noisy_data = add_noise(y)
    noisy_file_path = row['File_Path'].replace(".wav", "_noisy.wav")
    sf.write(noisy_file_path, noisy_data, sr)
    augmented_data.append({'Emotion': row['Emotion'], 'File_Path': noisy_file_path})

    # Apply time shifting
    shifted_data = shift_time(y)
    shifted_file_path = row['File_Path'].replace(".wav", "_shifted.wav")
    sf.write(shifted_file_path, shifted_data, sr)
    augmented_data.append({'Emotion': row['Emotion'], 'File_Path': shifted_file_path})

    # Apply pitch shifting
    pitched_data = change_pitch(y, sr)
    pitched_file_path = row['File_Path'].replace(".wav", "_pitched.wav")
    sf.write(pitched_file_path, pitched_data, sr)
    augmented_data.append({'Emotion': row['Emotion'], 'File_Path': pitched_file_path})

    # Apply speed change
    try:
        speed_data = change_speed(y, SPEED_FACTOR)
        speed_file_path = row['File_Path'].replace(".wav", "_speed.wav")
        sf.write(speed_file_path, speed_data, sr)
        augmented_data.append({'Emotion': row['Emotion'], 'File_Path': speed_file_path})
    except Exception as e:
        print(f"Error processing file {row['File_Path']} with speed factor {SPEED_FACTOR}: {e}")

augmented_df = pd.DataFrame(augmented_data)
final_df = pd.concat([ravdess_df, augmented_df], ignore_index=True)

print(final_df)
# Out:
#       Emotion                                          File_Path
# 0         sad  /content/ravdess/Train Set/Actor_08/03-01-04-0...
# 1     fearful  /content/ravdess/Train Set/Actor_08/03-01-06-0...
# 2     fearful  /content/ravdess/Train Set/Actor_08/03-01-06-0...
# 3     neutral  /content/ravdess/Train Set/Actor_08/03-01-01-0...
# 4       angry  /content/ravdess/Train Set/Actor_08/03-01-05-0...
# ...       ...                                                ...
# 3595  neutral  /content/ravdess/Train Set/Actor_11/03-01-01-0...
# 3596    angry  /content/ravdess/Train Set/Actor_11/03-01-05-0...
# 3597    angry  /content/ravdess/Train Set/Actor_11/03-01-05-0...
# 3598    angry  /content/ravdess/Train Set/Actor_11/03-01-05-0...
# 3599    angry  /content/ravdess/Train Set/Actor_11/03-01-05-0...
#
# [3600 rows x 2 columns]

# %% [markdown]
# ## **Feature Extraction**
# Feature extraction is a crucial step in the process of building a machine learning model. It involves transforming raw audio signals into a set of features that can be effectively used by machine learning algorithms. These features capture important characteristics of the audio signal, enabling the model to learn and make predictions more accurately.
#
# **Key Audio Features**
#
# Mel-Frequency Cepstral Coefficients (MFCCs)
#
# Chroma Features
#
# Spectrogram
#
# Zero-Crossing Rate (ZCR)
#
# Spectral Contrast
#
# Root Mean Square (RMS) Energy
#
# **Benefits of Feature Extraction**
#
# Dimensionality Reduction
#
# Improved Model Performance
#
# Interpretability

# %%
# Function to extract features from an audio file
def extract_features(file_path):
    y, sr = librosa.load(file_path, sr=None)

    # Extract MFCCs
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
    mfccs_mean = np.mean(mfccs, axis=1)

    # Extract Chroma feature
    chroma = librosa.feature.chroma_stft(y=y, sr=sr)
    chroma_mean = np.mean(chroma, axis=1)

    # Extract Spectral Contrast
    spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
    spectral_contrast_mean = np.mean(spectral_contrast, axis=1)

    # Extract Zero Crossing Rate
    zero_crossing_rate = librosa.feature.zero_crossing_rate(y)
    zero_crossing_rate_mean = np.mean(zero_crossing_rate)

    # Extract Root Mean Square Energy
    S = np.abs(librosa.stft(y))
    rmse = librosa.feature.rms(S=S)
    rmse_mean = np.mean(rmse)

    # Extract Mel-spectrogram
    mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
    mel_spectrogram_mean = np.mean(mel_spectrogram, axis=1)

    # Concatenate all features
    features = np.hstack((mfccs_mean, chroma_mean, spectral_contrast_mean, zero_crossing_rate_mean, rmse_mean, mel_spectrogram_mean))

    return features

# Extract features for each file in the final_df
features_list = []
for index, row in final_df.iterrows():
    features = extract_features(row['File_Path'])
    features_list.append(features)

# Convert features_list to a DataFrame
features_df = pd.DataFrame(features_list)

# Add the Emotion column from final_df to features_df
features_df['Emotion'] = final_df['Emotion']

print(features_df)
# Out:
#                0          1          2          3          4          5  \
# 0    -761.483032  71.773376  14.633630  23.550846   8.441536  18.252174
# 1    -578.749084  77.713196  -7.886116   6.420325   6.179074  11.582044
# 2    -603.779297  64.604401  -6.578300   7.780734   0.403219  11.610985
# 3    -712.075562  76.019432  12.366280  21.779139   8.561011  15.253534
# 4    -563.111694  60.146988   0.494722  13.174312   3.693977   1.640879
# ...          ...        ...        ...        ...        ...        ...
# 3595 -745.760376  59.496197  24.346766  18.837852   9.742865   5.289154
# 3596 -100.577202   9.175047  -0.578744  -2.271729  -5.858610  -3.676881
# 3597 -349.046295  24.155973  -7.570185   1.372138 -12.815687  -5.276818
# 3598 -386.030731  22.522659 -11.340427  -2.031952 -15.844463  -2.403362
# 3599 -378.480286  27.758413  -9.050571  -0.054251 -14.226600  -5.936737
#
#              6          7          8          9  ...           153  \
# 0     0.082437  11.601342  -4.075377  -4.015073  ...  2.753450e-07
# 1    -6.712715  11.458735  -4.745236  -7.660063  ...  5.277793e-06
# 2    -9.785730   7.472545  -5.785016 -11.302113  ...  6.178083e-06
# 3    -6.755793  12.945807  -7.801950  -2.183830  ...  2.365768e-07
# 4    -8.199457  10.116116  -0.262968  -3.105442  ...  1.973677e-06
# ...        ...        ...        ...        ...  ...           ...
# 3595  7.068676   0.805551  -1.026856   0.799600  ...  5.787830e-06
# 3596 -0.078612   0.162384  -3.168211  -4.537000  ...  1.065459e-01
# 3597 -2.116425  -2.632004  -7.344776  -9.453855  ...  2.101122e-02
# 3598 -4.301713  -4.500425 -11.750820  -4.136499  ...  5.146743e-03
# 3599 -2.682516  -2.823680  -7.578212 -10.884997  ...  9.027661e-03
#
#                154           155           156           157           158  \
# 0     2.188259e-07  1.856785e-07  1.398019e-07  8.540421e-08  4.493517e-08
# 1     3.719302e-06  2.213509e-06  1.630029e-06  1.564844e-06  1.206530e-06
# 2     5.385103e-06  3.829471e-06  3.135173e-06  2.302947e-06  1.313578e-06
# 3     1.238775e-07  7.980262e-08  5.268634e-08  5.747041e-08  6.682298e-08
# 4     1.374965e-06  1.356757e-06  1.204481e-06  8.438928e-07  5.584820e-07
# ...            ...           ...           ...           ...           ...
# 3595  1.264498e-05  8.422355e-06  7.647433e-06  5.562451e-06  5.231389e-06
# 3596  1.316626e-01  1.409008e-01  1.531622e-01  1.411589e-01  1.290988e-01
# 3597  4.231111e-02  5.593188e-02  6.915295e-02  6.197989e-02  4.412142e-02
# 3598  8.038521e-03  9.388122e-03  1.272593e-02  1.007209e-02  1.498596e-02
# 3599  1.582482e-02  2.346549e-02  2.951812e-02  2.800748e-02  1.799247e-02
#
#                159           160           161  Emotion
# 0     1.772313e-08  7.695315e-09  7.207385e-09      sad
# 1     8.235604e-07  1.017909e-07  8.651464e-09  fearful
# 2     4.618523e-07  4.138019e-08  8.273598e-09  fearful
# 3     3.255797e-08  9.113638e-09  7.661832e-09  neutral
# 4     3.253506e-07  4.106606e-08  8.009368e-09    angry
# ...            ...           ...           ...      ...
# 3595  6.082937e-06  3.539454e-06  3.700959e-07  neutral
# 3596  1.150497e-01  1.005095e-01  8.942561e-02    angry
# 3597  2.343144e-02  9.792976e-03  7.976508e-04    angry
# 3598  2.023338e-02  1.190898e-02  1.549095e-03    angry
# 3599  9.332476e-03  4.122147e-03  3.659953e-04    angry
#
# [3600 rows x 163 columns]

# %% [markdown]
# ## **Modelling**

# %%
import tensorflow as tf
from tensorflow.keras import layers

emotion_labels = pd.get_dummies(features_df['Emotion']).to_numpy()

# Define the neural network model
model = tf.keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(features_df.shape[1] - 1,)),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(64, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(5, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model using the entire dataset
model.fit(features_df.drop('Emotion', axis=1), emotion_labels, batch_size=10, epochs=300, validation_split=0.2)

# Save the model parameters
model.save_weights('/content/ravdess/softmax_regression_params.h5')
# Out:
# Epoch 1/300
# 288/288 [==============================] - 4s 4ms/step - loss: 2.2879 - accuracy: 0.2313 - val_loss: 1.4620 - val_accuracy: 0.2931
# Epoch 2/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.7510 - accuracy: 0.2767 - val_loss: 1.4835 - val_accuracy: 0.3264
# Epoch 3/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.6198 - accuracy: 0.2875 - val_loss: 1.4293 - val_accuracy: 0.3042
# Epoch 4/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.5651 - accuracy: 0.2847 - val_loss: 1.4501 - val_accuracy: 0.3222
# Epoch 5/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.5184 - accuracy: 0.3125 - val_loss: 1.4242 - val_accuracy: 0.3417
# Epoch 6/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.4977 - accuracy: 0.3208 - val_loss: 1.4509 - val_accuracy: 0.3486
# Epoch 7/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.4776 - accuracy: 0.3163 - val_loss: 1.4402 - val_accuracy: 0.3694
# Epoch 8/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.4723 - accuracy: 0.3309 - val_loss: 1.4228 - val_accuracy: 0.3750
# Epoch 9/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.4430 - accuracy: 0.3316 - val_loss: 1.4226 - val_accuracy: 0.3597
# Epoch 10/300
# 288/288 [==============================] - 2s 5ms/step - loss: 1.4305 - accuracy: 0.3503 - val_loss: 1.4486 - val_accuracy: 0.3861
# Epoch 11/300
# 288/288 [==============================] - 2s 5ms/step - loss: 1.4295 - accuracy: 0.3517 - val_loss: 1.4581 - val_accuracy: 0.3653
# Epoch 12/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.4244 - accuracy: 0.3694 - val_loss: 1.4102 - val_accuracy: 0.3556
# Epoch 13/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.4043 - accuracy: 0.3788 - val_loss: 1.4156 - val_accuracy: 0.3528
# Epoch 14/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.4076 - accuracy: 0.3715 - val_loss: 1.3696 - val_accuracy: 0.3708
# Epoch 15/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.3863 - accuracy: 0.3719 - val_loss: 1.3718 - val_accuracy: 0.3444
# Epoch 16/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.3971 - accuracy: 0.3837 - val_loss: 1.3884 - val_accuracy: 0.3694
# Epoch 17/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.3896 - accuracy: 0.3767 - val_loss: 1.3699 - val_accuracy: 0.3694
# Epoch 18/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.3820 - accuracy: 0.3684 - val_loss: 1.4376 - val_accuracy: 0.3722
# Epoch 19/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3785 - accuracy: 0.3847 - val_loss: 1.5305 - val_accuracy: 0.3639
# Epoch 20/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3690 - accuracy: 0.3917 - val_loss: 1.4538 - val_accuracy: 0.3611
# Epoch 21/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.3452 - accuracy: 0.3924 - val_loss: 1.4410 - val_accuracy: 0.3611
# Epoch 22/300
# 288/288 [==============================] - 2s 5ms/step - loss: 1.3501 - accuracy: 0.4000 - val_loss: 1.4468 - val_accuracy: 0.3764
# Epoch 23/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.3531 - accuracy: 0.4083 - val_loss: 1.4882 - val_accuracy: 0.3667
# Epoch 24/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3541 - accuracy: 0.3938 - val_loss: 1.5082 - val_accuracy: 0.3528
# Epoch 25/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3665 - accuracy: 0.3889 - val_loss: 1.4572 - val_accuracy: 0.3569
# Epoch 26/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3360 - accuracy: 0.4066 - val_loss: 1.5479 - val_accuracy: 0.3750
# Epoch 27/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3599 - accuracy: 0.3861 - val_loss: 1.6783 - val_accuracy: 0.3556
# Epoch 28/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3334 - accuracy: 0.4156 - val_loss: 1.5419 - val_accuracy: 0.3597
# Epoch 29/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3459 - accuracy: 0.4000 - val_loss: 1.6924 - val_accuracy: 0.3722
# Epoch 30/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3451 - accuracy: 0.3979 - val_loss: 1.5195 - val_accuracy: 0.3500
# Epoch 31/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3462 - accuracy: 0.4069 - val_loss: 1.7622 - val_accuracy: 0.3514
# Epoch 32/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3487 - accuracy: 0.4028 - val_loss: 1.5643 - val_accuracy: 0.3667
# Epoch 33/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3449 - accuracy: 0.4153 - val_loss: 1.5545 - val_accuracy: 0.3639
# Epoch 34/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.3536 - accuracy: 0.3962 - val_loss: 1.4439 - val_accuracy: 0.3639
# Epoch 35/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.3164 - accuracy: 0.4153 - val_loss: 1.4650 - val_accuracy: 0.3611
# Epoch 36/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.3360 - accuracy: 0.4156 - val_loss: 1.5201 - val_accuracy: 0.4000
# Epoch 37/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3065 - accuracy: 0.4323 - val_loss: 1.5114 - val_accuracy: 0.3889
# Epoch 38/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3267 - accuracy: 0.4122 - val_loss: 1.5959 - val_accuracy: 0.3722
# Epoch 39/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3370 - accuracy: 0.4059 - val_loss: 1.5114 - val_accuracy: 0.3569
# Epoch 40/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3219 - accuracy: 0.4191 - val_loss: 1.4610 - val_accuracy: 0.3597
# Epoch 41/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3082 - accuracy: 0.4073 - val_loss: 1.4182 - val_accuracy: 0.3819
# Epoch 42/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3298 - accuracy: 0.4083 - val_loss: 1.5218 - val_accuracy: 0.3847
# Epoch 43/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3539 - accuracy: 0.3990 - val_loss: 1.4720 - val_accuracy: 0.3833
# Epoch 44/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3324 - accuracy: 0.4122 - val_loss: 1.4622 - val_accuracy: 0.3806
# Epoch 45/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3161 - accuracy: 0.4028 - val_loss: 1.4600 - val_accuracy: 0.3764
# Epoch 46/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3119 - accuracy: 0.4344 - val_loss: 1.4638 - val_accuracy: 0.4069
# Epoch 47/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2966 - accuracy: 0.4281 - val_loss: 1.4614 - val_accuracy: 0.3792
# Epoch 48/300
# 288/288 [==============================] - 2s 5ms/step - loss: 1.3114 - accuracy: 0.4236 - val_loss: 1.4902 - val_accuracy: 0.3944
# Epoch 49/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.3110 - accuracy: 0.4139 - val_loss: 1.5701 - val_accuracy: 0.3819
# Epoch 50/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3136 - accuracy: 0.4215 - val_loss: 1.4759 - val_accuracy: 0.3889
# Epoch 51/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3198 - accuracy: 0.4215 - val_loss: 1.5609 - val_accuracy: 0.3694
# Epoch 52/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3140 - accuracy: 0.4236 - val_loss: 1.5647 - val_accuracy: 0.3819
# Epoch 53/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3110 - accuracy: 0.4309 - val_loss: 1.5772 - val_accuracy: 0.3833
# Epoch 54/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3063 - accuracy: 0.4361 - val_loss: 1.5894 - val_accuracy: 0.3903
# Epoch 55/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3091 - accuracy: 0.4264 - val_loss: 1.6152 - val_accuracy: 0.3903
# Epoch 56/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3025 - accuracy: 0.4337 - val_loss: 1.6383 - val_accuracy: 0.3903
# Epoch 57/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2979 - accuracy: 0.4309 - val_loss: 1.4953 - val_accuracy: 0.3958
# Epoch 58/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2936 - accuracy: 0.4389 - val_loss: 1.5477 - val_accuracy: 0.3889
# Epoch 59/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3046 - accuracy: 0.4354 - val_loss: 1.6113 - val_accuracy: 0.3764
# Epoch 60/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.3098 - accuracy: 0.4323 - val_loss: 1.5741 - val_accuracy: 0.4014
# Epoch 61/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.3158 - accuracy: 0.4253 - val_loss: 1.5697 - val_accuracy: 0.3722
# Epoch 62/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.3023 - accuracy: 0.4337 - val_loss: 1.6609 - val_accuracy: 0.3792
# Epoch 63/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3071 - accuracy: 0.4313 - val_loss: 1.6186 - val_accuracy: 0.3958
# Epoch 64/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.3018 - accuracy: 0.4288 - val_loss: 1.6484 - val_accuracy: 0.3722
# Epoch 65/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2974 - accuracy: 0.4372 - val_loss: 1.5860 - val_accuracy: 0.3819
# Epoch 66/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2897 - accuracy: 0.4309 - val_loss: 1.6235 - val_accuracy: 0.3875
# Epoch 67/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2759 - accuracy: 0.4396 - val_loss: 1.5780 - val_accuracy: 0.3903
# Epoch 68/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2988 - accuracy: 0.4306 - val_loss: 1.5504 - val_accuracy: 0.4056
# Epoch 69/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2973 - accuracy: 0.4319 - val_loss: 1.5439 - val_accuracy: 0.3806
# Epoch 70/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2811 - accuracy: 0.4597 - val_loss: 1.5300 - val_accuracy: 0.3875
# Epoch 71/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2889 - accuracy: 0.4382 - val_loss: 1.5264 - val_accuracy: 0.3625
# Epoch 72/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2830 - accuracy: 0.4340 - val_loss: 1.4918 - val_accuracy: 0.3792
# Epoch 73/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2957 - accuracy: 0.4306 - val_loss: 1.4665 - val_accuracy: 0.3875
# Epoch 74/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2859 - accuracy: 0.4451 - val_loss: 1.4674 - val_accuracy: 0.3833
# Epoch 75/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2968 - accuracy: 0.4347 - val_loss: 1.4895 - val_accuracy: 0.4014
# Epoch 76/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2940 - accuracy: 0.4483 - val_loss: 1.5159 - val_accuracy: 0.3861
# Epoch 77/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2817 - accuracy: 0.4441 - val_loss: 1.6088 - val_accuracy: 0.3917
# Epoch 78/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2879 - accuracy: 0.4437 - val_loss: 1.5402 - val_accuracy: 0.3833
# Epoch 79/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2876 - accuracy: 0.4420 - val_loss: 1.6022 - val_accuracy: 0.3792
# Epoch 80/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2714 - accuracy: 0.4493 - val_loss: 1.6200 - val_accuracy: 0.3750
# Epoch 81/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2655 - accuracy: 0.4563 - val_loss: 1.6535 - val_accuracy: 0.3847
# Epoch 82/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2803 - accuracy: 0.4517 - val_loss: 1.5478 - val_accuracy: 0.3847
# Epoch 83/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2826 - accuracy: 0.4465 - val_loss: 1.5257 - val_accuracy: 0.3833
# Epoch 84/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2906 - accuracy: 0.4358 - val_loss: 1.5518 - val_accuracy: 0.3889
# Epoch 85/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2662 - accuracy: 0.4538 - val_loss: 1.5556 - val_accuracy: 0.3875
# Epoch 86/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2760 - accuracy: 0.4410 - val_loss: 1.5527 - val_accuracy: 0.3750
# Epoch 87/300
# 288/288 [==============================] - 2s 5ms/step - loss: 1.2630 - accuracy: 0.4563 - val_loss: 1.5893 - val_accuracy: 0.3750
# Epoch 88/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2418 - accuracy: 0.4733 - val_loss: 1.6388 - val_accuracy: 0.3847
# Epoch 89/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2680 - accuracy: 0.4486 - val_loss: 1.5126 - val_accuracy: 0.3903
# Epoch 90/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2673 - accuracy: 0.4528 - val_loss: 1.5095 - val_accuracy: 0.3986
# Epoch 91/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2762 - accuracy: 0.4514 - val_loss: 1.4614 - val_accuracy: 0.3778
# Epoch 92/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2467 - accuracy: 0.4628 - val_loss: 1.4676 - val_accuracy: 0.3722
# Epoch 93/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2608 - accuracy: 0.4576 - val_loss: 1.4931 - val_accuracy: 0.3819
# Epoch 94/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2733 - accuracy: 0.4642 - val_loss: 1.5226 - val_accuracy: 0.3806
# Epoch 95/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2734 - accuracy: 0.4608 - val_loss: 1.5385 - val_accuracy: 0.3653
# Epoch 96/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2664 - accuracy: 0.4469 - val_loss: 1.4489 - val_accuracy: 0.3778
# Epoch 97/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2639 - accuracy: 0.4656 - val_loss: 1.4734 - val_accuracy: 0.3875
# Epoch 98/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2603 - accuracy: 0.4483 - val_loss: 1.4835 - val_accuracy: 0.3764
# Epoch 99/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2548 - accuracy: 0.4701 - val_loss: 1.5274 - val_accuracy: 0.3431
# Epoch 100/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2818 - accuracy: 0.4552 - val_loss: 1.4906 - val_accuracy: 0.3708
# Epoch 101/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2920 - accuracy: 0.4514 - val_loss: 1.4586 - val_accuracy: 0.3861
# Epoch 102/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2745 - accuracy: 0.4542 - val_loss: 1.4661 - val_accuracy: 0.3764
# Epoch 103/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2485 - accuracy: 0.4552 - val_loss: 1.5433 - val_accuracy: 0.3639
# Epoch 104/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2628 - accuracy: 0.4514 - val_loss: 1.6173 - val_accuracy: 0.3681
# Epoch 105/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2694 - accuracy: 0.4559 - val_loss: 1.4999 - val_accuracy: 0.3958
# Epoch 106/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2727 - accuracy: 0.4566 - val_loss: 1.6061 - val_accuracy: 0.3639
# Epoch 107/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2731 - accuracy: 0.4521 - val_loss: 1.5497 - val_accuracy: 0.3736
# Epoch 108/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2642 - accuracy: 0.4483 - val_loss: 1.5720 - val_accuracy: 0.3653
# Epoch 109/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2718 - accuracy: 0.4576 - val_loss: 1.5690 - val_accuracy: 0.3903
# Epoch 110/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2668 - accuracy: 0.4625 - val_loss: 1.5484 - val_accuracy: 0.3819
# Epoch 111/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2603 - accuracy: 0.4483 - val_loss: 1.5990 - val_accuracy: 0.3736
# Epoch 112/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2801 - accuracy: 0.4417 - val_loss: 1.6054 - val_accuracy: 0.3958
# Epoch 113/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2610 - accuracy: 0.4535 - val_loss: 1.5862 - val_accuracy: 0.3653
# Epoch 114/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2537 - accuracy: 0.4556 - val_loss: 1.6299 - val_accuracy: 0.3819
# Epoch 115/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2657 - accuracy: 0.4514 - val_loss: 1.6446 - val_accuracy: 0.3708
# Epoch 116/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2461 - accuracy: 0.4622 - val_loss: 1.5811 - val_accuracy: 0.3819
# Epoch 117/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2507 - accuracy: 0.4639 - val_loss: 1.5753 - val_accuracy: 0.3861
# Epoch 118/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2789 - accuracy: 0.4559 - val_loss: 1.5639 - val_accuracy: 0.3958
# Epoch 119/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2633 - accuracy: 0.4590 - val_loss: 1.5630 - val_accuracy: 0.3972
# Epoch 120/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2546 - accuracy: 0.4497 - val_loss: 1.5273 - val_accuracy: 0.3944
# Epoch 121/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2661 - accuracy: 0.4535 - val_loss: 1.5678 - val_accuracy: 0.3667
# Epoch 122/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2691 - accuracy: 0.4469 - val_loss: 1.4804 - val_accuracy: 0.4014
# Epoch 123/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2619 - accuracy: 0.4660 - val_loss: 1.5221 - val_accuracy: 0.3847
# Epoch 124/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2553 - accuracy: 0.4642 - val_loss: 1.5491 - val_accuracy: 0.3917
# Epoch 125/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2739 - accuracy: 0.4507 - val_loss: 1.4978 - val_accuracy: 0.3736
# Epoch 126/300
# 288/288 [==============================] - 2s 5ms/step - loss: 1.2692 - accuracy: 0.4538 - val_loss: 1.5026 - val_accuracy: 0.4028
# Epoch 127/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2804 - accuracy: 0.4531 - val_loss: 1.5334 - val_accuracy: 0.3792
# Epoch 128/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2646 - accuracy: 0.4510 - val_loss: 1.5510 - val_accuracy: 0.4014
# Epoch 129/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2666 - accuracy: 0.4455 - val_loss: 1.5508 - val_accuracy: 0.3778
# Epoch 130/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2752 - accuracy: 0.4406 - val_loss: 1.5741 - val_accuracy: 0.3806
# Epoch 131/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2618 - accuracy: 0.4528 - val_loss: 1.5685 - val_accuracy: 0.3958
# Epoch 132/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2879 - accuracy: 0.4479 - val_loss: 1.5197 - val_accuracy: 0.3958
# Epoch 133/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2680 - accuracy: 0.4469 - val_loss: 1.5470 - val_accuracy: 0.3931
# Epoch 134/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2822 - accuracy: 0.4549 - val_loss: 1.6378 - val_accuracy: 0.3597
# Epoch 135/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2748 - accuracy: 0.4476 - val_loss: 1.5718 - val_accuracy: 0.3903
# Epoch 136/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2703 - accuracy: 0.4444 - val_loss: 1.5748 - val_accuracy: 0.3736
# Epoch 137/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2754 - accuracy: 0.4476 - val_loss: 1.5558 - val_accuracy: 0.3861
# Epoch 138/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2849 - accuracy: 0.4497 - val_loss: 1.5916 - val_accuracy: 0.3833
# Epoch 139/300
# 288/288 [==============================] - 2s 5ms/step - loss: 1.2657 - accuracy: 0.4524 - val_loss: 1.5828 - val_accuracy: 0.4000
# Epoch 140/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2650 - accuracy: 0.4583 - val_loss: 1.5150 - val_accuracy: 0.3819
# Epoch 141/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2998 - accuracy: 0.4361 - val_loss: 1.5286 - val_accuracy: 0.4042
# Epoch 142/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2620 - accuracy: 0.4517 - val_loss: 1.5254 - val_accuracy: 0.3972
# Epoch 143/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2692 - accuracy: 0.4549 - val_loss: 1.5979 - val_accuracy: 0.3806
# Epoch 144/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2624 - accuracy: 0.4500 - val_loss: 1.6833 - val_accuracy: 0.3972
# Epoch 145/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2551 - accuracy: 0.4594 - val_loss: 1.6186 - val_accuracy: 0.3833
# Epoch 146/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2659 - accuracy: 0.4486 - val_loss: 1.6420 - val_accuracy: 0.3750
# Epoch 147/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2693 - accuracy: 0.4545 - val_loss: 1.6906 - val_accuracy: 0.3931
# Epoch 148/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2715 - accuracy: 0.4594 - val_loss: 1.5764 - val_accuracy: 0.3972
# Epoch 149/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2583 - accuracy: 0.4632 - val_loss: 1.6754 - val_accuracy: 0.3708
# Epoch 150/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2729 - accuracy: 0.4563 - val_loss: 1.6969 - val_accuracy: 0.3736
# Epoch 151/300
# 288/288 [==============================] - 2s 5ms/step - loss: 1.2809 - accuracy: 0.4382 - val_loss: 1.6361 - val_accuracy: 0.3722
# Epoch 152/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2811 - accuracy: 0.4514 - val_loss: 1.6050 - val_accuracy: 0.3806
# Epoch 153/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2802 - accuracy: 0.4549 - val_loss: 1.6795 - val_accuracy: 0.3944
# Epoch 154/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2767 - accuracy: 0.4469 - val_loss: 1.6832 - val_accuracy: 0.3875
# Epoch 155/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2625 - accuracy: 0.4549 - val_loss: 1.6447 - val_accuracy: 0.3819
# Epoch 156/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2772 - accuracy: 0.4437 - val_loss: 1.6152 - val_accuracy: 0.3972
# Epoch 157/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2671 - accuracy: 0.4476 - val_loss: 1.5794 - val_accuracy: 0.3944
# Epoch 158/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2764 - accuracy: 0.4535 - val_loss: 1.6221 - val_accuracy: 0.3833
# Epoch 159/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2759 - accuracy: 0.4521 - val_loss: 1.6411 - val_accuracy: 0.3972
# Epoch 160/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2772 - accuracy: 0.4406 - val_loss: 1.6566 - val_accuracy: 0.3958
# Epoch 161/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2766 - accuracy: 0.4552 - val_loss: 1.6243 - val_accuracy: 0.3903
# Epoch 162/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2788 - accuracy: 0.4427 - val_loss: 1.6921 - val_accuracy: 0.3833
# Epoch 163/300
# 288/288 [==============================] - 2s 5ms/step - loss: 1.2653 - accuracy: 0.4569 - val_loss: 1.6882 - val_accuracy: 0.3944
# Epoch 164/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2476 - accuracy: 0.4660 - val_loss: 1.7050 - val_accuracy: 0.3972
# Epoch 165/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2574 - accuracy: 0.4663 - val_loss: 1.6679 - val_accuracy: 0.3958
# Epoch 166/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2658 - accuracy: 0.4503 - val_loss: 1.7338 - val_accuracy: 0.3972
# Epoch 167/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2665 - accuracy: 0.4538 - val_loss: 1.6881 - val_accuracy: 0.4083
# Epoch 168/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2496 - accuracy: 0.4726 - val_loss: 1.6804 - val_accuracy: 0.3819
# Epoch 169/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2573 - accuracy: 0.4493 - val_loss: 1.7085 - val_accuracy: 0.3694
# Epoch 170/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2338 - accuracy: 0.4628 - val_loss: 1.7739 - val_accuracy: 0.3806
# Epoch 171/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2664 - accuracy: 0.4535 - val_loss: 1.7118 - val_accuracy: 0.3861
# Epoch 172/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2521 - accuracy: 0.4590 - val_loss: 1.6726 - val_accuracy: 0.4083
# Epoch 173/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2534 - accuracy: 0.4601 - val_loss: 1.7651 - val_accuracy: 0.3847
# Epoch 174/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2378 - accuracy: 0.4628 - val_loss: 1.7493 - val_accuracy: 0.3819
# Epoch 175/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2531 - accuracy: 0.4618 - val_loss: 1.8272 - val_accuracy: 0.3736
# Epoch 176/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2548 - accuracy: 0.4688 - val_loss: 1.7190 - val_accuracy: 0.3847
# Epoch 177/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2295 - accuracy: 0.4726 - val_loss: 1.7404 - val_accuracy: 0.3861
# Epoch 178/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2273 - accuracy: 0.4701 - val_loss: 1.7371 - val_accuracy: 0.3917
# Epoch 179/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2625 - accuracy: 0.4549 - val_loss: 1.6787 - val_accuracy: 0.3847
# Epoch 180/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2502 - accuracy: 0.4708 - val_loss: 1.7714 - val_accuracy: 0.3764
# Epoch 181/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2408 - accuracy: 0.4740 - val_loss: 1.8152 - val_accuracy: 0.3833
# Epoch 182/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2552 - accuracy: 0.4580 - val_loss: 1.7330 - val_accuracy: 0.4181
# Epoch 183/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2565 - accuracy: 0.4545 - val_loss: 1.7808 - val_accuracy: 0.3861
# Epoch 184/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2937 - accuracy: 0.4462 - val_loss: 1.7320 - val_accuracy: 0.3931
# Epoch 185/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2600 - accuracy: 0.4625 - val_loss: 1.7205 - val_accuracy: 0.3875
# Epoch 186/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2563 - accuracy: 0.4583 - val_loss: 1.7367 - val_accuracy: 0.4056
# Epoch 187/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2848 - accuracy: 0.4563 - val_loss: 1.6660 - val_accuracy: 0.4056
# Epoch 188/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2700 - accuracy: 0.4497 - val_loss: 1.6185 - val_accuracy: 0.4056
# Epoch 189/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2577 - accuracy: 0.4667 - val_loss: 1.6962 - val_accuracy: 0.3875
# Epoch 190/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2732 - accuracy: 0.4601 - val_loss: 1.7404 - val_accuracy: 0.4167
# Epoch 191/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2527 - accuracy: 0.4698 - val_loss: 1.6592 - val_accuracy: 0.3958
# Epoch 192/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2662 - accuracy: 0.4503 - val_loss: 1.6087 - val_accuracy: 0.4097
# Epoch 193/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2551 - accuracy: 0.4681 - val_loss: 1.6031 - val_accuracy: 0.3847
# Epoch 194/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2633 - accuracy: 0.4590 - val_loss: 1.6193 - val_accuracy: 0.3986
# Epoch 195/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2571 - accuracy: 0.4646 - val_loss: 1.5846 - val_accuracy: 0.3889
# Epoch 196/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2571 - accuracy: 0.4611 - val_loss: 1.6279 - val_accuracy: 0.3806
# Epoch 197/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2691 - accuracy: 0.4590 - val_loss: 1.6196 - val_accuracy: 0.3653
# Epoch 198/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2731 - accuracy: 0.4521 - val_loss: 1.5831 - val_accuracy: 0.3903
# Epoch 199/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2594 - accuracy: 0.4583 - val_loss: 1.6487 - val_accuracy: 0.4111
# Epoch 200/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2568 - accuracy: 0.4573 - val_loss: 1.6391 - val_accuracy: 0.4097
# Epoch 201/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2712 - accuracy: 0.4451 - val_loss: 1.6525 - val_accuracy: 0.3792
# Epoch 202/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2649 - accuracy: 0.4660 - val_loss: 1.6386 - val_accuracy: 0.4292
# Epoch 203/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2495 - accuracy: 0.4604 - val_loss: 1.6639 - val_accuracy: 0.3889
# Epoch 204/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2569 - accuracy: 0.4660 - val_loss: 1.6539 - val_accuracy: 0.3986
# Epoch 205/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2489 - accuracy: 0.4590 - val_loss: 1.6399 - val_accuracy: 0.3819
# Epoch 206/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2448 - accuracy: 0.4691 - val_loss: 1.6434 - val_accuracy: 0.3819
# Epoch 207/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2486 - accuracy: 0.4601 - val_loss: 1.6564 - val_accuracy: 0.4167
# Epoch 208/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2521 - accuracy: 0.4628 - val_loss: 1.6051 - val_accuracy: 0.4181
# Epoch 209/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2721 - accuracy: 0.4542 - val_loss: 1.6326 - val_accuracy: 0.4069
# Epoch 210/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2485 - accuracy: 0.4677 - val_loss: 1.6913 - val_accuracy: 0.4028
# Epoch 211/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2666 - accuracy: 0.4535 - val_loss: 1.6999 - val_accuracy: 0.4042
# Epoch 212/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2361 - accuracy: 0.4663 - val_loss: 1.7706 - val_accuracy: 0.4069
# Epoch 213/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2508 - accuracy: 0.4743 - val_loss: 1.7092 - val_accuracy: 0.4125
# Epoch 214/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2368 - accuracy: 0.4622 - val_loss: 1.7388 - val_accuracy: 0.3681
# Epoch 215/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2524 - accuracy: 0.4642 - val_loss: 1.7274 - val_accuracy: 0.4236
# Epoch 216/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2390 - accuracy: 0.4670 - val_loss: 1.7038 - val_accuracy: 0.3917
# Epoch 217/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2210 - accuracy: 0.4670 - val_loss: 1.7735 - val_accuracy: 0.3944
# Epoch 218/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2498 - accuracy: 0.4663 - val_loss: 1.7249 - val_accuracy: 0.4042
# Epoch 219/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2419 - accuracy: 0.4684 - val_loss: 1.7133 - val_accuracy: 0.3833
# Epoch 220/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2245 - accuracy: 0.4792 - val_loss: 1.7559 - val_accuracy: 0.3875
# Epoch 221/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2463 - accuracy: 0.4576 - val_loss: 1.7690 - val_accuracy: 0.3556
# Epoch 222/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2381 - accuracy: 0.4639 - val_loss: 1.7034 - val_accuracy: 0.3764
# Epoch 223/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2415 - accuracy: 0.4792 - val_loss: 1.7015 - val_accuracy: 0.4014
# Epoch 224/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2473 - accuracy: 0.4719 - val_loss: 1.6773 - val_accuracy: 0.3958
# Epoch 225/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2329 - accuracy: 0.4649 - val_loss: 1.7044 - val_accuracy: 0.4000
# Epoch 226/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2476 - accuracy: 0.4663 - val_loss: 1.7380 - val_accuracy: 0.4153
# Epoch 227/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2402 - accuracy: 0.4812 - val_loss: 1.7251 - val_accuracy: 0.4222
# Epoch 228/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2245 - accuracy: 0.4681 - val_loss: 1.7620 - val_accuracy: 0.4250
# Epoch 229/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2390 - accuracy: 0.4774 - val_loss: 1.7451 - val_accuracy: 0.4042
# Epoch 230/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2361 - accuracy: 0.4726 - val_loss: 1.8020 - val_accuracy: 0.4208
# Epoch 231/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2503 - accuracy: 0.4628 - val_loss: 1.8079 - val_accuracy: 0.4236
# Epoch 232/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2675 - accuracy: 0.4597 - val_loss: 1.8015 - val_accuracy: 0.4139
# Epoch 233/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2511 - accuracy: 0.4639 - val_loss: 1.7939 - val_accuracy: 0.4111
# Epoch 234/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2551 - accuracy: 0.4625 - val_loss: 1.7813 - val_accuracy: 0.4167
# Epoch 235/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2389 - accuracy: 0.4729 - val_loss: 1.8656 - val_accuracy: 0.4014
# Epoch 236/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2364 - accuracy: 0.4719 - val_loss: 1.8059 - val_accuracy: 0.4167
# Epoch 237/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2453 - accuracy: 0.4701 - val_loss: 1.8016 - val_accuracy: 0.3986
# Epoch 238/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2489 - accuracy: 0.4594 - val_loss: 1.7954 - val_accuracy: 0.4028
# Epoch 239/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2413 - accuracy: 0.4604 - val_loss: 1.7791 - val_accuracy: 0.4097
# Epoch 240/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2608 - accuracy: 0.4601 - val_loss: 1.7937 - val_accuracy: 0.4000
# Epoch 241/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2458 - accuracy: 0.4632 - val_loss: 1.7520 - val_accuracy: 0.4042
# Epoch 242/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2588 - accuracy: 0.4674 - val_loss: 1.7269 - val_accuracy: 0.4222
# Epoch 243/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2325 - accuracy: 0.4653 - val_loss: 1.8419 - val_accuracy: 0.4000
# Epoch 244/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2389 - accuracy: 0.4681 - val_loss: 1.7625 - val_accuracy: 0.4208
# Epoch 245/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2266 - accuracy: 0.4819 - val_loss: 1.8046 - val_accuracy: 0.3986
# Epoch 246/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2599 - accuracy: 0.4531 - val_loss: 1.8089 - val_accuracy: 0.4028
# Epoch 247/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2529 - accuracy: 0.4667 - val_loss: 1.8146 - val_accuracy: 0.3778
# Epoch 248/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2293 - accuracy: 0.4653 - val_loss: 1.8491 - val_accuracy: 0.3861
# Epoch 249/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2499 - accuracy: 0.4635 - val_loss: 1.7618 - val_accuracy: 0.4111
# Epoch 250/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2560 - accuracy: 0.4597 - val_loss: 1.7707 - val_accuracy: 0.4139
# Epoch 251/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2547 - accuracy: 0.4674 - val_loss: 1.7196 - val_accuracy: 0.4028
# Epoch 252/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2484 - accuracy: 0.4663 - val_loss: 1.7268 - val_accuracy: 0.4069
# Epoch 253/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2357 - accuracy: 0.4635 - val_loss: 1.7797 - val_accuracy: 0.3847
# Epoch 254/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2607 - accuracy: 0.4573 - val_loss: 1.6639 - val_accuracy: 0.4222
# Epoch 255/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2458 - accuracy: 0.4583 - val_loss: 1.7332 - val_accuracy: 0.4111
# Epoch 256/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2454 - accuracy: 0.4753 - val_loss: 1.6750 - val_accuracy: 0.4000
# Epoch 257/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2416 - accuracy: 0.4778 - val_loss: 1.7593 - val_accuracy: 0.4083
# Epoch 258/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2509 - accuracy: 0.4719 - val_loss: 1.7465 - val_accuracy: 0.3944
# Epoch 259/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2420 - accuracy: 0.4663 - val_loss: 1.7101 - val_accuracy: 0.4083
# Epoch 260/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2560 - accuracy: 0.4608 - val_loss: 1.7144 - val_accuracy: 0.3917
# Epoch 261/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2410 - accuracy: 0.4694 - val_loss: 1.6400 - val_accuracy: 0.3889
# Epoch 262/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2586 - accuracy: 0.4566 - val_loss: 1.6578 - val_accuracy: 0.3944
# Epoch 263/300
# 288/288 [==============================] - 2s 5ms/step - loss: 1.2484 - accuracy: 0.4628 - val_loss: 1.6595 - val_accuracy: 0.3792
# Epoch 264/300
# 288/288 [==============================] - 2s 5ms/step - loss: 1.2471 - accuracy: 0.4753 - val_loss: 1.6712 - val_accuracy: 0.3778
# Epoch 265/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2321 - accuracy: 0.4743 - val_loss: 1.5579 - val_accuracy: 0.4153
# Epoch 266/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.1982 - accuracy: 0.4802 - val_loss: 1.5787 - val_accuracy: 0.4222
# Epoch 267/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2438 - accuracy: 0.4760 - val_loss: 1.6749 - val_accuracy: 0.4083
# Epoch 268/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2455 - accuracy: 0.4767 - val_loss: 1.6295 - val_accuracy: 0.4014
# Epoch 269/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2296 - accuracy: 0.4764 - val_loss: 1.6815 - val_accuracy: 0.4083
# Epoch 270/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2426 - accuracy: 0.4726 - val_loss: 1.6240 - val_accuracy: 0.4222
# Epoch 271/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2338 - accuracy: 0.4736 - val_loss: 1.6639 - val_accuracy: 0.4097
# Epoch 272/300
# 288/288 [==============================] - 1s 5ms/step - loss: 1.2430 - accuracy: 0.4799 - val_loss: 1.6250 - val_accuracy: 0.4125
# Epoch 273/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2463 - accuracy: 0.4708 - val_loss: 1.6884 - val_accuracy: 0.3972
# Epoch 274/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2563 - accuracy: 0.4656 - val_loss: 1.6208 - val_accuracy: 0.3944
# Epoch 275/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2663 - accuracy: 0.4549 - val_loss: 1.6561 - val_accuracy: 0.3806
# Epoch 276/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2569 - accuracy: 0.4622 - val_loss: 1.6436 - val_accuracy: 0.3903
# Epoch 277/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2540 - accuracy: 0.4660 - val_loss: 1.6356 - val_accuracy: 0.4056
# Epoch 278/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2388 - accuracy: 0.4788 - val_loss: 1.6708 - val_accuracy: 0.4167
# Epoch 279/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2365 - accuracy: 0.4656 - val_loss: 1.7059 - val_accuracy: 0.3875
# Epoch 280/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2511 - accuracy: 0.4556 - val_loss: 1.7012 - val_accuracy: 0.3944
# Epoch 281/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2595 - accuracy: 0.4674 - val_loss: 1.6385 - val_accuracy: 0.4083
# Epoch 282/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2256 - accuracy: 0.4799 - val_loss: 1.6416 - val_accuracy: 0.3972
# Epoch 283/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2383 - accuracy: 0.4715 - val_loss: 1.6206 - val_accuracy: 0.4222
# Epoch 284/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2355 - accuracy: 0.4733 - val_loss: 1.6423 - val_accuracy: 0.4014
# Epoch 285/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2279 - accuracy: 0.4788 - val_loss: 1.6032 - val_accuracy: 0.4042
# Epoch 286/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2363 - accuracy: 0.4760 - val_loss: 1.5902 - val_accuracy: 0.4000
# Epoch 287/300
# 288/288 [==============================] - 2s 7ms/step - loss: 1.2308 - accuracy: 0.4819 - val_loss: 1.6851 - val_accuracy: 0.3889
# Epoch 288/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2220 - accuracy: 0.4889 - val_loss: 1.6253 - val_accuracy: 0.4111
# Epoch 289/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2228 - accuracy: 0.4816 - val_loss: 1.6275 - val_accuracy: 0.4014
# Epoch 290/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2486 - accuracy: 0.4705 - val_loss: 1.6369 - val_accuracy: 0.4097
# Epoch 291/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2436 - accuracy: 0.4726 - val_loss: 1.5988 - val_accuracy: 0.3861
# Epoch 292/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2287 - accuracy: 0.4677 - val_loss: 1.5875 - val_accuracy: 0.4153
# Epoch 293/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2347 - accuracy: 0.4646 - val_loss: 1.5970 - val_accuracy: 0.4139
# Epoch 294/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2460 - accuracy: 0.4576 - val_loss: 1.6487 - val_accuracy: 0.3847
# Epoch 295/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2264 - accuracy: 0.4674 - val_loss: 1.6227 - val_accuracy: 0.3861
# Epoch 296/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2440 - accuracy: 0.4535 - val_loss: 1.6653 - val_accuracy: 0.4097
# Epoch 297/300
# 288/288 [==============================] - 1s 3ms/step - loss: 1.2361 - accuracy: 0.4674 - val_loss: 1.6393 - val_accuracy: 0.3847
# Epoch 298/300
# 288/288 [==============================] - 1s 4ms/step - loss: 1.2260 - accuracy: 0.4736 - val_loss: 1.6327 - val_accuracy: 0.3889
# Epoch 299/300
# 288/288 [==============================] - 2s 6ms/step - loss: 1.2333 - accuracy: 0.4625 - val_loss: 1.5624 - val_accuracy: 0.4069
# Epoch 300/300
# 288/288 [==============================] - 2s 5ms/step - loss: 1.2370 - accuracy: 0.4705 - val_loss: 1.5923 - val_accuracy: 0.3944

# %% [markdown]
# ## **TESTING**

# %%
test_set_list = os.listdir(test_set_path)

test_data = []

for dir in test_set_list:
  actor = os.listdir(test_set_path+ '/'+ dir)
  for file in actor:
    part = file.split('.')[0]
    part = part.split('-')
    emotion = emotions.get(part[2], None)
    if emotion is not None and emotion in observed_emotions:
      file_path = os.path.join(test_set_path, dir, file)
      test_data.append({'Emotion': emotion, 'File_Path': file_path})

test_ravdess_df = pd.DataFrame(test_data)

# %%
test_features_list = []
for index, row in test_ravdess_df.iterrows():
    features = extract_features(row['File_Path'])
    test_features_list.append(features)

# Convert features_list to a DataFrame
test_features_df = pd.DataFrame(test_features_list)

# Add the Emotion column from final_df to features_df
test_features_df['Emotion'] = test_ravdess_df['Emotion']

# %%
test_emotion_labels = pd.get_dummies(test_features_df['Emotion']).to_numpy()
test_features_df_modified = test_features_df.drop('Emotion', axis=1)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np

def load_model_weights(model, filepath: str):
    try:
        model.load_weights(filepath)
    except Exception as e:
        raise

def predict_labels(model, features: np.ndarray) -> np.ndarray:
    try:
        predictions = model.predict(features)
        predicted_classes = np.argmax(predictions, axis=1)
        return predicted_classes
    except Exception as e:
        raise

def calculate_metrics(true_labels: np.ndarray, predicted_labels: np.ndarray):
    try:
        accuracy = accuracy_score(true_labels, predicted_labels)
        precision = precision_score(true_labels, predicted_labels, average='weighted', zero_division=0)
        recall = recall_score(true_labels, predicted_labels, average='weighted')
        f1 = f1_score(true_labels, predicted_labels, average='weighted')

        print(f"Accuracy: {accuracy * 100:.2f}%")
        print(f"Precision: {precision * 100:.2f}%")
        print(f"Recall: {recall * 100:.2f}%")
        print(f"F1 Score: {f1 * 100:.2f}%")

        return accuracy, precision, recall, f1
    except Exception as e:
        raise

def test_model(model, test_features_df_modified: np.ndarray, test_emotion_labels: np.ndarray, weights_filepath: str):
    """
    Test the model with the provided features and labels.

    Parameters:
    model: The machine learning model to be tested.
    test_features_df_modified (np.ndarray): Modified test features.
    test_emotion_labels (np.ndarray): True emotion labels for the test data.
    weights_filepath (str): Path to the saved model weights.

    Returns:
    tuple: Accuracy, precision, recall, and F1 score of the model on the test data.
    """
    # Load the saved model parameters
    load_model_weights(model, weights_filepath)

    # Make predictions on the test set
    y_pred_class = predict_labels(model, test_features_df_modified)

    # Calculate and return metrics
    return calculate_metrics(np.argmax(test_emotion_labels, axis=1), y_pred_class)

# Example call to the function
# Assuming 'model', 'test_features_df_modified', 'test_emotion_labels', and 'weights_filepath' are defined
accuracy, precision, recall, f1 = test_model(model, test_features_df_modified, test_emotion_labels, '/content/ravdess/softmax_regression_params.h5')

# %% [markdown]
# ## **Conclusion**
#
# The developed machine learning model for Speech Emotion Recognition (SER) achieves an accuracy ranging from 50% to 55%. This performance can be enhanced with access to a larger dataset, as the currently used RAVDESS dataset is relatively small. Expanding the dataset will provide more diverse training examples, leading to improved model accuracy and robustness.
